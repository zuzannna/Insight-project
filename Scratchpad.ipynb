# %%
from SPARQLWrapper import SPARQLWrapper, JSON

# %%
sparql = SPARQLWrapper("http://dbpedia.org/sparql")
sparql.setQuery("""
    PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
    SELECT ?label
    WHERE { <http://dbpedia.org/resource/Asturias> rdfs:label ?label }
""")
sparql.setReturnFormat(JSON)
results = sparql.query().convert()

for result in results["results"]["bindings"]:
    print(result["label"]["value"])
# Out:
# Asturias
# منطقة أستورياس
# Asturien
# Asturias
# Asturies
# Asturie
# アストゥリアス州
# Asturië (regio)
# Asturia
# Astúrias
# Астурия
# 阿斯图里亚斯

# %%
sparql = SPARQLWrapper("http://dbpedia.org/sparql")
sparql.setQuery("""
PREFIX crm: <http://erlangen-crm.org/current/>
PREFIX fts: <http://www.ontotext.com/owlim/fts#>

PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#>
SELECT DISTINCT ?object 
{ ?object crm:P102_has_title ?title .                    #Find the title resource for an object
  # ?title rdfs:label ?label .                              #find the label attached to that title
  FILTER(REGEX(?label, "Rosetta Stone"))                  #match the 'Rosetta Stone' token by regular expression
}
""")
sparql.setReturnFormat(JSON)
results = sparql.query().convert()

for result in results["results"]["bindings"]:
    print(result["label"]["value"])

# %%
results["results"]
# Out:
# {u'bindings': [], u'distinct': False, u'ordered': True}

# %%
import json
from pprint import pprint

with open('paintings_1000.json') as data_file:    
    data = json.load(data_file)

pprint(data)
# Out:
# {u'head': {u'vars': [u'painting']},
#  u'results': {u'bindings': [{u'painting': {u'type': u'uri',
#                                            u'value': u'http://collection.britishmuseum.org/id/object/JCF9001'}},
#                             {u'painting': {u'type': u'uri',
#                                            u'value': u'http://collection.britishmuseum.org/id/object/J_1982-0701-0-3'}},
#                             {u'painting': {u'type': u'uri',
#                                            u'value': u'http://collection.britishmuseum.org/id/object/147'}},
#                             {u'painting': {u'type': u'uri',
#                                            u'value': u'http://collection.britishmuseum.org/id/object/JCF8994'}},
#                             {u'painting': {u'type': u'uri',
#                                            u'value': u'http://collection.britishmuseum.org/id/object/J_1982-0701-0-5'}},
#                             {u'painting': {u'type': u'uri',
# ...

# %%
print(data['results']['bindings'])
# Out:
# [{u'painting': {u'type': u'uri', u'value': u'http://collection.britishmuseum.org/id/object/JCF9001'}}, {u'painting': {u'type': u'uri', u'value': u'http://collection.britishmuseum.org/id/object/J_1982-0701-0-3'}}, {u'painting': {u'type': u'uri', u'value': u'http://collection.britishmuseum.org/id/object/147'}}, {u'painting': {u'type': u'uri', u'value': u'http://collection.britishmuseum.org/id/object/JCF8994'}}, {u'painting': {u'type': u'uri', u'value': u'http://collection.britishmuseum.org/id/object/J_1982-0701-0-5'}}, {u'painting': {u'type': u'uri', u'value': u'http://collection.britishmuseum.org/id/object/149'}}, {u'painting': {u'type': u'uri', u'value': u'http://collection.britishmuseum.org/id/object/JCF12245'}}, {u'painting': {u'type': u'uri', u'value': u'http://collection.britishmuseum.org/id/object/J_1982-0701-0-6-1-10'}}, {u'painting': {u'type': u'uri', u'value': u'http://collection.britishmuseum.org/id/object/150'}}, {u'painting': {u'type': u'uri', u'value': u'http://collection
# ...

# %%
html_doc='''

<!DOCTYPE html>
<html data-engine="webkit">
    <head>
        <meta charset="UTF-8">
        <title>
            GENERIC 150
        </title>
        <link href="/favicon.ico" rel="icon" type="image/x-icon">
        <link type="text/css" rel="stylesheet" href="/css/summer-MQovY3NzL2Jvb3RzdHJhcC5taW4uY3Nz.css">
        <link type="text/css" rel="stylesheet" href="/css/forest-eNoz5NJPLi7WT8svSi0u0U0sLclPzs8tyEktSdUDiqNIJgMphGByaXFJfq5uSUZqbqp+VmFpalGlbmmmLkQYpAwA0IAhYg.css">
        <link type="text/css" rel="stylesheet" href="/css/eNoz4NJPLi7WT8svSi0u0QUS+aVFyal6QDGIRH55Tmaubnl+UXZSal5yBkIiLTU1JSkxORskAgBf6BkO.css">
        <script type="text/javascript" src="/js/summer-eNpNzDEKgDAMQNHduzSlLp4nlggtjalJCnp7Fwuu78NPS6wW6zVIn5BggxW4nFDt54DDJQv3Rk4z2WAmDVjxnnSIknkwyQXbxF3EzRX7930Bkh0nzA.js"></script>
        <script type="text/javascript" src="/js/forest-eNptzEESgjAMheG9d0mguvEgXiAtAVsLGZJ2we2p4zCjjNv_fYm7dMm6tFbWDWoEh3e83jBUKzLjHBdM9kWwPJmGptyfLZByAaVl4ib602pBJeeH_GYIIq_IRxyUpg8kn_n0wRN4vx5xFGUr7V7fbgeS+0VJ.js"></script>
        <script type="text/javascript" src="/js/eNoz4NLPKtZPyy9KLS7RTSwtyU_Ozy3ISS1J1csqRpYCEvmlRckgYQDYjBLL.js"></script>
        <script>
            $(function() {
                $.extend(forest, {
                    context: 'all',
                    language: 'en',
                    inference: 'explicit'
                });            
            });
        </script>
        <script>
            forest = {
                limit: 10000,
                uri: 'http://localhost:8080'
            }
        </script>
        <script type="text/javascript" src="/js/eNoz4NLPKtZPS01NSUpMztbLKgbz88tzMnN1y_OLspNS85IzgMIADyAODg.js"></script>
        <script>
            summer = {
                contextPath: ''
            };
        </script>
    </head>
    <body>
        <div class="layout">
            <header>
                <div class="page">
                    <p id="logo">
                        <a href="/">
                            OWLIM Workbench</a>
                    </p>
                    <ul>
                        <li>
                            <a href="#">Admin <span class="arr">▼</span></a>
                            <ul>
                                <li>
                                    <a href="/admin/owlim">Repositories</a>
                                </li>
                                <li>
                                    <a href="/admin/security/view">Users</a>
                                </li>
                                <li>
                                    <a href="/admin/info">System Info</a>
                                </li>
                            </ul>
                        </li>
                        <li>
                            <a href="#">Data <span class="arr">▼</span></a>
                            <ul>
                                <li>
                                    <a href="/data/import">Import</a>
                                </li>
                                <li>
                                    <a href="/data/export">Export</a>
                                </li>
                            </ul>
                        </li>
                        <li>
                            <a href="#">SPARQL <span class="arr">▼</span></a>
                            <ul>
                                <li>
                                    <a href="/sparql">Query</a>
                                </li>
                                <li>
                                    <a href="/update">Update</a>
                                </li>
                            </ul>
                        </li>
                    </ul>
                </div>
            </header><!-- 		Feedback stuff      -->
            <div style="display: none;" class="feedback-overlay">
            </div><!--        End of feedbacstuff -->
            <div class="container">
                <div class="page">
                    <div>
                        <div>
                            <div class="resource-info">
                                <h1>
                                    150
                                    <sup><img title="RDF Rank 0.00" height="15" alt="RDF Rank 0.00" width="42" src="/img/rank0.gif"></sup>
                                </h1>
                                <p class="source">
                                    <span>Source:</span><a href="http://collection.britishmuseum.org/id/object/150">http://collection.britishmuseum.org/id/object/150</a>
                                </p>
                            </div>
                        </div>
                        <div>
                            <form action="/resource/search" class="input-append" method="get">
                                <fieldset>
                                    <label for="q">
                                        RDF Search and Explore
                                    </label>
                                    <input id="q" name="q" class="q" type="text" size="40">
                                </fieldset>
                                <input type="hidden" name="_form" value="/resource">
                            </form>
                        </div>
                        <div>
                            <div id="selection" class="selection">
                                <ul class="resource-tabs">
                                    <li class="selected"><a href="/resource?uri=http%3A%2F%2Fcollection.britishmuseum.org%2Fid%2Fobject%2F150">
        
                    Subject
                    <span>
                        (<span id="count" class="count">83</span>)</span></a>
                                    </li>
                                    <li>
                                        <a href="/resource?uri=http%3A%2F%2Fcollection.britishmuseum.org%2Fid%2Fobject%2F150&amp;role=predicate">
                    Predicate</a>
                                    </li>
                                    <li>
                                        <a href="/resource?uri=http%3A%2F%2Fcollection.britishmuseum.org%2Fid%2Fobject%2F150&amp;role=object">
                    Object</a>
                                    </li>
                                    <li>
                                        <a href="/resource?uri=http%3A%2F%2Fcollection.britishmuseum.org%2Fid%2Fobject%2F150&amp;role=all">
                    All</a>
                                    </li>
                                </ul>
                                <div>
                                    <div class="resource-formats">
                                        <p>
                                            Download in:
                                        </p>
                                        <ul>
                                            <li>
                                                <a title="Download in JSON" class="format" href="/resource?uri=http%3A%2F%2Fcollection.britishmuseum.org%2Fid%2Fobject%2F150&amp;format=json">JSON</a>
                                            </li>
                                            <li>
                                                <a title="Download in RDF" class="format" href="/resource?uri=http%3A%2F%2Fcollection.britishmuseum.org%2Fid%2Fobject%2F150&amp;format=rdf">RDF</a>
                                            </li>
                                            <li>
                                                <a title="Download in N3/Turtle" class="format" href="/resource?uri=http%3A%2F%2Fcollection.britishmuseum.org%2Fid%2Fobject%2F150&amp;format=n3">N3/Turtle</a>
                                            </li>
                                            <li>
                                                <a title="Download in NTriples" class="format" href="/resource?uri=http%3A%2F%2Fcollection.britishmuseum.org%2Fid%2Fobject%2F150&amp;format=nt">N-Triples</a>
                                            </li>
                                        </ul>
                                    </div>
                                </div>
                            </div>
                            <div class="pull-right">
                                <form action="/resource" method="get">
                                    <label class="pull-left">
                                        Named Graph
                                        
                                        <select id="context-select" name="context-select">
                                            <option selected="selected" value="all">
                                                All
                                            </option>
                                            <option value="http://dbpedia.org">
                                                DBpedia
                                            </option>
                                            <option value="http://freebase.com">
                                                Freebase
                                            </option>
                                            <option value="http://umbel.org/umbel#">
                                                Umbel
                                            </option>
                                        </select>
                                    </label>
                                    <label class="pull-left">
                                        Language
                                        
                                        <select id="language-select" name="language-select">
                                            <option value="all">
                                                All
                                            </option>
                                            <option selected="selected" value="en">
                                                English
                                            </option>
                                            <option value="es">
                                                Español
                                            </option>
                                            <option value="pt">
                                                Português
                                            </option>
                                            <option value="fr">
                                                Français
                                            </option>
                                            <option value="de">
                                                Deutsch
                                            </option>
                                            <option value="ru">
                                                Русский
                                            </option>
                                            <option value="ja">
                                                日本語
                                            </option>
                                            <option value="bg">
                                                Български
                                            </option>
                                        </select>
                                    </label>
                                    <label class="pull-left">
                                        Inference
                                        
                                        <select id="inference-select" name="inference-select">
                                            <option value="all">
                                                Explicit and implicit
                                            </option>
                                            <option selected="selected" value="explicit">
                                                Explicit only
                                            </option>
                                            <option value="implicit">
                                                Implicit only
                                            </option>
                                        </select>
                                    </label>
                                    <input type="hidden" name="_form" value="/resource">
                                </form>
                            </div>
                            <div class="clearfix">
                            </div>
                            <div id="results" class="results">
                                <div><table class="table table-striped table-bordered"><caption>
        
                    Statements in which the resource exists as a subject.</caption><thead><tr><th style="width:30%">Predicate</th><th style="width:70%">Object</th></tr></thead><tbody><tr class="even"><td><span>
                                <a href="/resource/rdf/type" title="http://www.w3.org/1999/02/22-rdf-syntax-ns#type">rdf:type</a></span></td><td>
                                                    <div>
                                                        <span><a href="/resource/ecrm/E22_Man-Made_Object" title="http://erlangen-crm.org/current/E22_Man-Made_Object" class="explicit">ecrm:E22_Man-Made_Object</a></span>
                                                    </div></td></tr><tr class="odd"><td><span>
                            
                                <a href="/resource/ecrm/P45_consists_of" title="http://erlangen-crm.org/current/P45_consists_of">ecrm:P45_consists_of</a></span></td><td>
                                                    <div>
                                                        <span><a href="/resource/thes/x11409" title="http://collection.britishmuseum.org/id/thesauri/x11409" class="explicit">thes:x11409</a></span>
                                                    </div></td></tr><tr class="even"><td><span>
                            
                                <a href="/resource/ecrm/P51_has_former_or_current_owner" title="http://erlangen-crm.org/current/P51_has_former_or_current_owner">ecrm:P51_has_former_or_curr...</a></span></td><td>
                                                    <div>
                                                        <span><a href="/resource?uri=http%3A%2F%2Fcollection.britishmuseum.org%2Fid%2Fperson-institution%2F1480" title="http://collection.britishmuseum.org/id/person-institution/1480" class="explicit">http://collection.britishmuseum.org/id/person-institution/1480</a></span>,
                                                        <span><a href="/resource?uri=http%3A%2F%2Fcollection.britishmuseum.org%2Fid%2Fperson-institution%2F1482" title="http://collection.britishmuseum.org/id/person-institution/1482" class="explicit">http://collection.britishmuseum.org/id/person-institution/1482</a></span>,
                                                        <span><a href="/resource?uri=http%3A%2F%2Fcollection.britishmuseum.org%2Fid%2Fperson-institution%2F167473" title="http://collection.britishmuseum.org/id/person-institution/167473" class="explicit">http://collection.britishmuseum.org/id/person-institution/167473</a></span>,
                                                        <span><a href="/resource?uri=http%3A%2F%2Fcollection.britishmuseum.org%2Fid%2Fperson-institution%2F177164" title="http://collection.britishmuseum.org/id/person-institution/177164" class="explicit">http://collection.britishmuseum.org/id/person-institution/177164</a></span>,
                                                        <span><a href="/resource?uri=http%3A%2F%2Fcollection.britishmuseum.org%2Fid%2Fperson-institution%2F4778" title="http://collection.britishmuseum.org/id/person-institution/4778" class="explicit">http://collection.britishmuseum.org/id/person-institution/4778</a></span>
                                                    </div></td></tr><tr class="odd"><td><span>
                            
                                <a href="/resource/ecrm/P62_depicts" title="http://erlangen-crm.org/current/P62_depicts">ecrm:P62_depicts</a></span></td><td>
                                                    <div>
                                                        <span><a href="/resource?uri=http%3A%2F%2Fcollection.britishmuseum.org%2Fid%2Fperson-institution%2F166158" title="http://collection.britishmuseum.org/id/person-institution/166158" class="explicit">http://collection.britishmuseum.org/id/person-institution/166158</a></span>,
                                                        <span><a href="/resource?uri=http%3A%2F%2Fcollection.britishmuseum.org%2Fid%2Fperson-institution%2F4717" title="http://collection.britishmuseum.org/id/person-institution/4717" class="explicit">http://collection.britishmuseum.org/id/person-institution/4717</a></span>,
                                                        <span><a href="/resource?uri=http%3A%2F%2Fcollection.britishmuseum.org%2Fid%2Fperson-institution%2F6969" title="http://collection.britishmuseum.org/id/person-institution/6969" class="explicit">http://collection.britishmuseum.org/id/person-institution/6969</a></span>,
                                                        <span><a href="/resource?uri=http%3A%2F%2Fcollection.britishmuseum.org%2Fid%2Fperson-institution%2F8528" title="http://collection.britishmuseum.org/id/person-institution/8528" class="explicit">http://collection.britishmuseum.org/id/person-institution/8528</a></span>
                                                    </div></td></tr><tr class="even"><td><span>
                            
                                <a href="/resource/bmo/PX_has_main_representation" title="http://collection.britishmuseum.org/id/ontology/PX_has_main_representation">bmo:PX_has_main_representat...</a></span></td><td>
                                                    <div>
                                                        <span><a href="/resource?uri=http%3A%2F%2Fwww.britishmuseum.org%2Fcollectionimages%2FAN00228%2FAN00228903_001_l.jpg" title="http://www.britishmuseum.org/collectionimages/AN00228/AN00228903_001_l.jpg" class="explicit">http://www.britishmuseum.org/collectionimages/AN00228/AN00228903_001_l.jpg</a></span>
                                                    </div></td></tr><tr class="odd"><td><span>
                            
                                <a href="/resource/ecrm/P52_has_current_owner" title="http://erlangen-crm.org/current/P52_has_current_owner">ecrm:P52_has_current_owner</a></span></td><td>
                                                    <div>
                                                        <span><a href="/resource/thesIdentifier/the-british-museum" title="http://collection.britishmuseum.org/id/the-british-museum" class="explicit">thesIdentifier:the-british-museum</a></span>
                                                    </div></td></tr><tr class="even"><td><span>
                            
                                <a href="/resource/ecrm/P138i_has_representation" title="http://erlangen-crm.org/current/P138i_has_representation">ecrm:P138i_has_representati...</a></span></td><td>
                                                    <div>
                                                        <span><a href="/resource?uri=http%3A%2F%2Fwww.britishmuseum.org%2Fcollectionimages%2FAN00228%2FAN00228904_001_l.jpg" title="http://www.britishmuseum.org/collectionimages/AN00228/AN00228904_001_l.jpg" class="explicit">http://www.britishmuseum.org/collectionimages/AN00228/AN00228904_001_l.jpg</a></span>,
                                                        <span><a href="/resource?uri=http%3A%2F%2Fwww.britishmuseum.org%2Fcollectionimages%2FAN00228%2FAN00228905_001_l.jpg" title="http://www.britishmuseum.org/collectionimages/AN00228/AN00228905_001_l.jpg" class="explicit">http://www.britishmuseum.org/collectionimages/AN00228/AN00228905_001_l.jpg</a></span>,
                                                        <span><a href="/resource?uri=http%3A%2F%2Fwww.britishmuseum.org%2Fcollectionimages%2FAN00228%2FAN00228906_001_l.jpg" title="http://www.britishmuseum.org/collectionimages/AN00228/AN00228906_001_l.jpg" class="explicit">http://www.britishmuseum.org/collectionimages/AN00228/AN00228906_001_l.jpg</a></span>,
                                                        <span><a href="/resource?uri=http%3A%2F%2Fwww.britishmuseum.org%2Fcollectionimages%2FAN00228%2FAN00228907_001_l.jpg" title="http://www.britishmuseum.org/collectionimages/AN00228/AN00228907_001_l.jpg" class="explicit">http://www.britishmuseum.org/collectionimages/AN00228/AN00228907_001_l.jpg</a></span>,
                                                        <span><a href="/resource?uri=http%3A%2F%2Fwww.britishmuseum.org%2Fcollectionimages%2FAN00228%2FAN00228908_001_l.jpg" title="http://www.britishmuseum.org/collectionimages/AN00228/AN00228908_001_l.jpg" class="explicit">http://www.britishmuseum.org/collectionimages/AN00228/AN00228908_001_l.jpg</a></span>,
                                                        <span><a href="/resource?uri=http%3A%2F%2Fwww.britishmuseum.org%2Fcollectionimages%2FAN00228%2FAN00228909_001_l.jpg" title="http://www.britishmuseum.org/collectionimages/AN00228/AN00228909_001_l.jpg" class="explicit">http://www.britishmuseum.org/collectionimages/AN00228/AN00228909_001_l.jpg</a></span>,
                                                        <span><a href="/resource?uri=http%3A%2F%2Fwww.britishmuseum.org%2Fcollectionimages%2FAN00228%2FAN00228910_001_l.jpg" title="http://www.britishmuseum.org/collectionimages/AN00228/AN00228910_001_l.jpg" class="explicit">http://www.britishmuseum.org/collectionimages/AN00228/AN00228910_001_l.jpg</a></span>,
                                                        <span><a href="/resource?uri=http%3A%2F%2Fwww.britishmuseum.org%2Fcollectionimages%2FAN00228%2FAN00228911_001_l.jpg" title="http://www.britishmuseum.org/collectionimages/AN00228/AN00228911_001_l.jpg" class="explicit">http://www.britishmuseum.org/collectionimages/AN00228/AN00228911_001_l.jpg</a></span>,
                                                        <span><a href="/resource?uri=http%3A%2F%2Fwww.britishmuseum.org%2Fcollectionimages%2FAN00228%2FAN00228912_001_l.jpg" title="http://www.britishmuseum.org/collectionimages/AN00228/AN00228912_001_l.jpg" class="explicit">http://www.britishmuseum.org/collectionimages/AN00228/AN00228912_001_l.jpg</a></span>,
                                                        <span><a href="/resource?uri=http%3A%2F%2Fwww.britishmuseum.org%2Fcollectionimages%2FAN00228%2FAN00228913_001_l.jpg" title="http://www.britishmuseum.org/collectionimages/AN00228/AN00228913_001_l.jpg" class="explicit">http://www.britishmuseum.org/collectionimages/AN00228/AN00228913_001_l.jpg</a></span>,
                                                        <span><a href="/resource?uri=http%3A%2F%2Fwww.britishmuseum.org%2Fcollectionimages%2FAN00229%2FAN00229601_001_l.jpg" title="http://www.britishmuseum.org/collectionimages/AN00229/AN00229601_001_l.jpg" class="explicit">http://www.britishmuseum.org/collectionimages/AN00229/AN00229601_001_l.jpg</a></span>,
                                                        <span><a href="/resource?uri=http%3A%2F%2Fwww.britishmuseum.org%2Fcollectionimages%2FAN00230%2FAN00230742_001_l.jpg" title="http://www.britishmuseum.org/collectionimages/AN00230/AN00230742_001_l.jpg" class="explicit">http://www.britishmuseum.org/collectionimages/AN00230/AN00230742_001_l.jpg</a></span>
                                                    </div></td></tr><tr class="odd"><td><span>
                            
                                <a href="/resource/ecrm/P128_carries" title="http://erlangen-crm.org/current/P128_carries">ecrm:P128_carries</a></span></td><td>
                                                    <div>
                                                        <span><a href="/resource?uri=http%3A%2F%2Fcollection.britishmuseum.org%2Fid%2Fobject%2FJCF12245%2Fconcept%2F1" title="http://collection.britishmuseum.org/id/object/JCF12245/concept/1" class="explicit">http://collection.britishmuseum.org/id/object/JCF12245/concept/1</a></span>,
                                                        <span><a href="/resource?uri=http%3A%2F%2Fcollection.britishmuseum.org%2Fid%2Fobject%2FJCF12245%2Fconcept%2F2" title="http://collection.britishmuseum.org/id/object/JCF12245/concept/2" class="explicit">http://collection.britishmuseum.org/id/object/JCF12245/concept/2</a></span>,
                                                        <span><a href="/resource?uri=http%3A%2F%2Fcollection.britishmuseum.org%2Fid%2Fobject%2FJCF12245%2Ftitle%2F1" title="http://collection.britishmuseum.org/id/object/JCF12245/title/1" class="explicit">http://collection.britishmuseum.org/id/object/JCF12245/title/1</a></span>,
                                                        <span><a href="/resource?uri=http%3A%2F%2Fcollection.britishmuseum.org%2Fid%2Fobject%2FJCF12245%2Ftitle%2F2" title="http://collection.britishmuseum.org/id/object/JCF12245/title/2" class="explicit">http://collection.britishmuseum.org/id/object/JCF12245/title/2</a></span>,
                                                        <span><a href="/resource?uri=http%3A%2F%2Fcollection.britishmuseum.org%2Fid%2Fobject%2FJCF12245%2Ftitle%2F3" title="http://collection.britishmuseum.org/id/object/JCF12245/title/3" class="explicit">http://collection.britishmuseum.org/id/object/JCF12245/title/3</a></span>
                                                    </div></td></tr><tr class="even"><td><span>
                            
                                <a href="/resource/ecrm/P70i_is_documented_in" title="http://erlangen-crm.org/current/P70i_is_documented_in">ecrm:P70i_is_documented_in</a></span></td><td>
                                                    <div>
                                                        <span><a href="/resource?uri=http%3A%2F%2Fcollection.britishmuseum.org%2Fid%2Fbibliography%2F16" title="http://collection.britishmuseum.org/id/bibliography/16" class="explicit">http://collection.britishmuseum.org/id/bibliography/16</a></span>,
                                                        <span><a href="/resource?uri=http%3A%2F%2Fcollection.britishmuseum.org%2Fid%2Fbibliography%2F3" title="http://collection.britishmuseum.org/id/bibliography/3" class="explicit">http://collection.britishmuseum.org/id/bibliography/3</a></span>,
                                                        <span><a href="/resource?uri=http%3A%2F%2Fcollection.britishmuseum.org%2Fid%2Fbibliography%2F32" title="http://collection.britishmuseum.org/id/bibliography/32" class="explicit">http://collection.britishmuseum.org/id/bibliography/32</a></span>
                                                    </div></td></tr><tr class="odd"><td><span>
                            
                                <a href="/resource/ecrm/P50_has_current_keeper" title="http://erlangen-crm.org/current/P50_has_current_keeper">ecrm:P50_has_current_keeper</a></span></td><td>
                                                    <div>
                                                        <span><a href="/resource/thesIdentifier/the-british-museum" title="http://collection.britishmuseum.org/id/the-british-museum" class="explicit">thesIdentifier:the-british-museum</a></span>,
                                                        <span><a href="/resource?uri=http%3A%2F%2Fcollection.britishmuseum.org%2Fid%2Fthesauri%2Fdepartment%2FA" title="http://collection.britishmuseum.org/id/thesauri/department/A" class="explicit">http://collection.britishmuseum.org/id/thesauri/department/A</a></span>
                                                    </div></td></tr><tr class="even"><td><span>
                            
                                <a href="/resource/ecrm/P30i_custody_transferred_through" title="http://erlangen-crm.org/current/P30i_custody_transferred_through">ecrm:P30i_custody_transferr...</a></span></td><td>
                                                    <div>
                                                        <span><a href="/resource?uri=http%3A%2F%2Fcollection.britishmuseum.org%2Fid%2Fobject%2FJCF12245%2Facquisition" title="http://collection.britishmuseum.org/id/object/JCF12245/acquisition" class="explicit">http://collection.britishmuseum.org/id/object/JCF12245/acquisition</a></span>
                                                    </div></td></tr><tr class="odd"><td><span>
                            
                                <a href="/resource/ecrm/P1_is_identified_by" title="http://erlangen-crm.org/current/P1_is_identified_by">ecrm:P1_is_identified_by</a></span></td><td>
                                                    <div>
                                                        <span><a href="/resource?uri=http%3A%2F%2Fcollection.britishmuseum.org%2Fid%2Fobject%2FJCF12245%2Fcodexid" title="http://collection.britishmuseum.org/id/object/JCF12245/codexid" class="explicit">http://collection.britishmuseum.org/id/object/JCF12245/codexid</a></span>,
                                                        <span><a href="/resource?uri=http%3A%2F%2Fcollection.britishmuseum.org%2Fid%2Fobject%2FJCF12245%2Fotherid" title="http://collection.britishmuseum.org/id/object/JCF12245/otherid" class="explicit">http://collection.britishmuseum.org/id/object/JCF12245/otherid</a></span>,
                                                        <span><a href="/resource?uri=http%3A%2F%2Fcollection.britishmuseum.org%2Fid%2Fobject%2FJCF12245%2Fregno" title="http://collection.britishmuseum.org/id/object/JCF12245/regno" class="explicit">http://collection.britishmuseum.org/id/object/JCF12245/regno</a></span>
                                                    </div></td></tr><tr class="even"><td><span>
                            
                                <a href="/resource/ecrm/P24i_changed_ownership_through" title="http://erlangen-crm.org/current/P24i_changed_ownership_through">ecrm:P24i_changed_ownership...</a></span></td><td>
                                                    <div>
                                                        <span><a href="/resource?uri=http%3A%2F%2Fcollection.britishmuseum.org%2Fid%2Fobject%2FJCF12245%2Facquisition" title="http://collection.britishmuseum.org/id/object/JCF12245/acquisition" class="explicit">http://collection.britishmuseum.org/id/object/JCF12245/acquisition</a></span>
                                                    </div></td></tr><tr class="odd"><td><span>
                            
                                <a href="/resource/ecrm/P49_has_former_or_current_keeper" title="http://erlangen-crm.org/current/P49_has_former_or_current_keeper">ecrm:P49_has_former_or_curr...</a></span></td><td>
                                                    <div>
                                                        <span><a href="/resource?uri=http%3A%2F%2Fcollection.britishmuseum.org%2Fid%2Fperson-institution%2F1480" title="http://collection.britishmuseum.org/id/person-institution/1480" class="explicit">http://collection.britishmuseum.org/id/person-institution/1480</a></span>,
                                                        <span><a href="/resource?uri=http%3A%2F%2Fcollection.britishmuseum.org%2Fid%2Fperson-institution%2F177164" title="http://collection.britishmuseum.org/id/person-institution/177164" class="explicit">http://collection.britishmuseum.org/id/person-institution/177164</a></span>
                                                    </div></td></tr><tr class="even"><td><span>
                            
                                <a href="/resource/bmo/PX_object_type" title="http://collection.britishmuseum.org/id/ontology/PX_object_type">bmo:PX_object_type</a></span></td><td>
                                                    <div>
                                                        <span><a href="/resource/thes/x5126" title="http://collection.britishmuseum.org/id/thesauri/x5126" class="explicit">thes:x5126</a></span>,
                                                        <span><a href="/resource/thes/x8227" title="http://collection.britishmuseum.org/id/thesauri/x8227" class="explicit">thes:x8227</a></span>
                                                    </div></td></tr><tr class="odd"><td><span>
                            
                                <a href="/resource/bmo/PX_curatorial_comment" title="http://collection.britishmuseum.org/id/ontology/PX_curatorial_comment">bmo:PX_curatorial_comment</a></span></td><td>
                                                    <div>
                                                        <span><span>Asahi 1996



&ldquo;&#33459;&#23431;&#22530;&rdquo;&#12394;&#12427;&#20154;&#29289;&#12364;&#26126;&#27835;25&#24180;&#65288;1892&#65289;&#12395;&#30011;&#24086;&#12398;&#24460;&#26360;&#12365;&#12395;&#35352;&#12375;&#12383;&#12392;&#12371;&#12429;&#12391;&#12399;&#12289;&#24444;&#12398;&#29238;&#12364;&#32117;&#12364;&#22909;&#12365;&#12391;&#24195;&#37325;&#12395;&#12388;&#12356;&#12390;&#32117;&#12434;&#23398;&#12435;&#12391;&#12356;&#12383;&#12290;&#33459;&#23431;&#22530;&#12399;&#24195;&#37325;&#12364;&#25551;&#12356;&#12383;&#26412;&#22259;&#12364;&#31665;&#12398;&#24213;&#12395;&#30496;&#12387;&#12390;&#12356;&#12383;&#12398;&#12434;&#35211;&#12388;&#12369;&#12289;&#30011;&#24086;&#12395;&#20181;&#31435;&#12390;&#12383;&#12392;&#12356;&#12358;&#12290;&#26360;&#21517;&#12399;&#12394;&#12356;&#12364;&#12289;&#12371;&#12398;10&#26522;&#12398;&#30053;&#30011;&#39080;&#12398;&#20316;&#21697;&#12399;&#30906;&#12363;&#12395;&#24195;&#37325;&#12398;&#24109;&#30011;&#12398;&#27096;&#24335;&#12391;&#12354;&#12427;&#12290;&#24195;&#37325;&#12398;&#21360;&#31456;&#12434;&#25345;&#12388;&#12289;&#12424;&#12367;&#20284;&#12383;&#20182;&#12398;&#20316;&#21697;&#12399;&#20309;&#28857;&#12363;&#12289;&#12501;&#12522;&#12540;&#12450;&#32654;&#34899;&#39208;&#65288;Freer Gallery of Art (eds) &lsquo;The Freer Gallery of Art II: Japan&rsquo;, Tokyo, Kodansha n.d. (?1972), no.66&#65289;&#12420;&#31859;&#22269;&#35696;&#20250;&#22259;&#26360;&#39208;&#65288;Lee, Sherman E. &lsquo;The Sketchbooks of Hiroshige&rsquo; 2 Vols, New York, George Braziller, 1984&#65289;&#12398;&#34101;&#21697;&#12394;&#12393;&#30693;&#12425;&#12428;&#12427;&#12398;&#12391;&#12289;&#26412;&#20316;&#21697;&#12418;&#24195;&#37325;&#12398;&#25163;&#12395;&#12394;&#12427;&#12418;&#12398;&#12391;&#12354;&#12429;&#12358;&#12290;&#24107;&#21280;&#12364;&#24351;&#23376;&#12398;&#20351;&#12358;&#25163;&#26412;&#12392;&#12375;&#12390;&#12289;&#20197;&#21069;&#12395;&#25551;&#12356;&#12383;&#20316;&#21697;&#12398;&#27169;&#20889;&#12434;&#20316;&#12427;&#12371;&#12392;&#12399;&#12424;&#12367;&#12354;&#12427;&#12371;&#12392;&#12391;&#12289;&#32626;&#21517;&#12399;&#12394;&#12356;&#12398;&#12364;&#26222;&#36890;&#12391;&#12354;&#12427;&#12290;&#30011;&#24086;&#12398;&#20840;10&#22259;&#12398;&#20027;&#38988;&#12399;&#27425;&#12398;&#12392;&#12362;&#12426;&#12391;&#12354;&#12427;&#12290;



&#65288;&#20234;&#34276;&#32043;&#32340;&#65288;&#21315;&#33865;&#24066;&#32654;&#34899;&#39208;&#65289;&#65289;    



1&#65306;&#19977;&#30058;&#21471;

2&#65306;&#22818;&#12391;&#21513;&#21407;&#12395;&#36938;&#12406;&#30007;

3&#65306;&#35937;&#12434;&#36899;&#12428;&#12383;&#20013;&#22269;&#20154;&#65288;&#65311;&#65289;&#34892;&#21015;

4&#65306;&#27468;&#33310;&#20238;&#29378;&#35328;&#12300;&#21152;&#36032;&#35211;&#23665;&#26087;&#37670;&#32117;&#12301;&#12398;&#23721;&#34276;&#12364;&#23614;&#19978;&#12434;&#33609;&#23653;&#12391;&#12358;&#12388;&#12392;&#12371;&#12429;

5&#65306;&#33310;&#12434;&#33310;&#12358;&#31070;&#23448;

6&#65306;&#24120;&#22812;&#28783;&#12398;&#33031;&#12434;&#36890;&#12426;&#36942;&#12366;&#12427;&#21253;&#12415;&#12434;&#25265;&#12360;&#12383;&#22899;&#12290;&#23614;&#19978;&#12398;&#24544;&#23455;&#12394;&#19979;&#22899;&#12362;&#21021;&#12363;&#65311;

7&#65306;&#20632;&#12434;&#25345;&#12387;&#12383;&#24460;&#12429;&#21521;&#12365;&#12398;&#21161;&#20845;

8&#65306;&#22303;&#25163;&#12398;&#26716;&#33457;

9&#65306;&#24481;&#31806;&#12398;&#19979;&#12363;&#12425;&#36867;&#12370;&#12427;&#22899;&#19977;&#23470;&#12398;&#29483;

10&#65306;&#35211;&#31435;&#36948;&#30952;&#36938;&#22899;&#22823;&#39318;&#32117;



&#65288;&#20234;&#34276;&#32043;&#32340;&#65288;&#21315;&#33865;&#24066;&#32654;&#34899;&#39208;&#65289;&#65289;</span></span>,
                                                        <span><span>Clark 1992  



The postscript to the album by one 'Houdo shujin', dated October 1892, explains that his father had been fond of painting and had studied with Hiroshige and that he had found these sheets of paintings by the master preserved at the bottom of a chest and had them bound into an album. Though unsigned, the ten abbreviated sketches are certainly in Hiroshige's most convivial style, and other versions of several of the compositions bearing a Hiroshige seal are in the collections of the Freer Gallery of Art, Washington, DC (Freer Gallery of Art (eds), 'The Freer Gallery of Art II: Japan', Tokyo, Kodansha, n.d. (?1972), no. 66) and Library of Congress (Lee 1984, vol. II, pls 4, 11, 19), confirming the attribution. It was customary for teachers to make copies, often unsigned, of previously worked-out compositions for pupils to use as study material ('tehon'). The ten subjects in the album are:



1     Sambaso dancer.

2    Man dreaming of pleasure quarters.

3    (?)Chinese with an elephant in a procession.

4    Iwafuji striking Onoe with the sandal, from the Kabuki play 'Kagamiyama kokyo no nishiki-e' (illustrated).

5    Shinto priest dancing.

6    Woman with a parcel walking past a large lantern in the street. (?)Ohatsu, the faithful maid.

7    Sukeroku with his umbrella, seen from behind.

8    Blossoming cherry trees on riverbank.

9    The Third Princess's cat running out from under a blind.

10    Bust portrait of a courtesan as Daruma.



Literature:

Hillier, Jack. 'Hokusai Drawings'. London, Phaidon, 1966, pls 64, 66.

Hillier, Jack, 'The Harari Collection of Japanese Paintings and Prints'. Vol. 2, London, Lund Humphries, 1970, no. 183.

Hillier, Jack. 'Japanese Drawings of the 18th and 19th Centuries'. Washington, DC, International Exhibitions Foundation, 1980, no. 121.</span></span>
                                                    </div></td></tr><tr class="even"><td><span>
                            
                                <a href="/resource/bmo/PX_display_wrap" title="http://collection.britishmuseum.org/id/ontology/PX_display_wrap">bmo:PX_display_wrap</a></span></td><td>
                                                    <div>
                                                        <span><span>Acquisition (From) :: Harari, Michael to The British Museum ::</span></span>,
                                                        <span><span>Acquisition date :: 1982 ::</span></span>,
                                                        <span><span>Associated Person (Depicted - IP) :: Daruma :: 10</span></span>,
                                                        <span><span>Associated Person (Depicted - IR) :: Hanakawado Sukeroku :: 7</span></span>,
                                                        <span><span>Associated Person (Depicted - IR) :: Onoe :: 4</span></span>,
                                                        <span><span>Associated Person (Depicted - IR) :: Tsubone Iwafuji :: 4</span></span>,
                                                        <span><span>Bibliograpic reference :: Asahi 1996 91 ::</span></span>,
                                                        <span><span>Bibliograpic reference :: Clark 1992 136 ::</span></span>,
                                                        <span><span>Bibliograpic reference :: Hizo Nihon bijutsu taikan Vol 3 BW 55 ::</span></span>,
                                                        <span><span>Consists of :: paper ::</span></span>,
                                                        <span><span>Dimension Height :: 23.50cm ::</span></span>,
                                                        <span><span>Dimension Length :: 32.70cm :: opening</span></span>,
                                                        <span><span>Dimension Width :: 16.60cm :: closed</span></span>,
                                                        <span><span>Inscription note :: The postscript to the album by one 'Houdo shujin', dated October 1892, explains that his father had been fond of painting and had studied with Hiroshige and that he had found these sheets of paintings by the master preserved at the bottom of a chest and had them bound into an album.</span></span>,
                                                        <span><span>Object type :: album ::</span></span>,
                                                        <span><span>Object type :: painting ::</span></span>,
                                                        <span><span>Production (Likely/Unlikely):: Attributed to Hiroshige, Ando ::</span></span>,
                                                        <span><span>Production (Painted in) :: Japan ::</span></span>,
                                                        <span><span>Production Period / Culture :: Ansei Era :: ?</span></span>,
                                                        <span><span>Production Period / Culture :: Kaei Era :: ?</span></span>,
                                                        <span><span>Production Period / Culture :: Koka Era :: ?</span></span>,
                                                        <span><span>Production Period / Culture :: Tenpo Era :: ?</span></span>,
                                                        <span><span>Production date :: 1830-1860 ::</span></span>,
                                                        <span><span>Subject :: courtesan/prostitute ::</span></span>,
                                                        <span><span>Subject :: fuzoku ::</span></span>,
                                                        <span><span>Uses technique :: painted ::</span></span>
                                                    </div></td></tr><tr class="odd"><td><span>
                            
                                <a href="/resource/bmo/PX_physical_description" title="http://collection.britishmuseum.org/id/ontology/PX_physical_description">bmo:PX_physical_description</a></span></td><td>
                                                    <div>
                                                        <span><span>Painting, folding album. Ten abbreviated sketches on miscellaneous subjects: 

1: Dancer.

2: Man dreaming of pleasure quarters.

3: (?)Chinese with elephant in procession.

4: Iwafuji striking Onoe with sandal, from Kabuki play 'Kagamiyama kokyo no nishiki-e'.

5: Shinto priest dancing.

6: Woman with parcel walking past large lantern in street.

7: Sukeroku with his umbrella, seen from behind.

8: Blossoming cherry trees on riverbank.

9: Third Princess's cat running out from under blind.

10: Bust portrait of courtesan as Daruma.

Ink and colour on paper. Annotated.</span></span>
                                                    </div></td></tr><tr class="even"><td><span>
                            
                                <a href="/resource/ecrm/P108i_was_produced_by" title="http://erlangen-crm.org/current/P108i_was_produced_by">ecrm:P108i_was_produced_by</a></span></td><td>
                                                    <div>
                                                        <span><a href="/resource?uri=http%3A%2F%2Fcollection.britishmuseum.org%2Fid%2Fobject%2FJCF12245%2Fproduction" title="http://collection.britishmuseum.org/id/object/JCF12245/production" class="explicit">http://collection.britishmuseum.org/id/object/JCF12245/production</a></span>
                                                    </div></td></tr><tr class="odd"><td><span>
                            
                                <a href="/resource/ecrm/P43_has_dimension" title="http://erlangen-crm.org/current/P43_has_dimension">ecrm:P43_has_dimension</a></span></td><td>
                                                    <div>
                                                        <span><a href="/resource?uri=http%3A%2F%2Fcollection.britishmuseum.org%2Fid%2Fobject%2FJCF12245%2Fheight%2F1" title="http://collection.britishmuseum.org/id/object/JCF12245/height/1" class="explicit">http://collection.britishmuseum.org/id/object/JCF12245/height/1</a></span>,
                                                        <span><a href="/resource?uri=http%3A%2F%2Fcollection.britishmuseum.org%2Fid%2Fobject%2FJCF12245%2Flength%2F1" title="http://collection.britishmuseum.org/id/object/JCF12245/length/1" class="explicit">http://collection.britishmuseum.org/id/object/JCF12245/length/1</a></span>,
                                                        <span><a href="/resource?uri=http%3A%2F%2Fcollection.britishmuseum.org%2Fid%2Fobject%2FJCF12245%2Fwidth%2F1" title="http://collection.britishmuseum.org/id/object/JCF12245/width/1" class="explicit">http://collection.britishmuseum.org/id/object/JCF12245/width/1</a></span>
                                                    </div></td></tr><tr class="even"><td><span>
                            
                                <a href="/resource/ecrm/P48_has_preferred_identifier" title="http://erlangen-crm.org/current/P48_has_preferred_identifier">ecrm:P48_has_preferred_iden...</a></span></td><td>
                                                    <div>
                                                        <span><a href="/resource?uri=http%3A%2F%2Fcollection.britishmuseum.org%2Fid%2Fobject%2FJCF12245%2Fprn" title="http://collection.britishmuseum.org/id/object/JCF12245/prn" class="explicit">http://collection.britishmuseum.org/id/object/JCF12245/prn</a></span>
                                                    </div></td></tr><tr class="odd"><td><span>
                            
                                <a href="/resource/ecrm/P65_shows_visual_item" title="http://erlangen-crm.org/current/P65_shows_visual_item">ecrm:P65_shows_visual_item</a></span></td><td>
                                                    <div>
                                                        <span><a href="/resource?uri=http%3A%2F%2Fcollection.britishmuseum.org%2Fid%2Fobject%2FJCF12245%2Fimage%2F1" title="http://collection.britishmuseum.org/id/object/JCF12245/image/1" class="explicit">http://collection.britishmuseum.org/id/object/JCF12245/image/1</a></span>,
                                                        <span><a href="/resource?uri=http%3A%2F%2Fcollection.britishmuseum.org%2Fid%2Fobject%2FJCF12245%2Fimage%2F2" title="http://collection.britishmuseum.org/id/object/JCF12245/image/2" class="explicit">http://collection.britishmuseum.org/id/object/JCF12245/image/2</a></span>,
                                                        <span><a href="/resource?uri=http%3A%2F%2Fcollection.britishmuseum.org%2Fid%2Fobject%2FJCF12245%2Fimage%2F3" title="http://collection.britishmuseum.org/id/object/JCF12245/image/3" class="explicit">http://collection.britishmuseum.org/id/object/JCF12245/image/3</a></span>,
                                                        <span><a href="/resource?uri=http%3A%2F%2Fcollection.britishmuseum.org%2Fid%2Fobject%2FJCF12245%2Fimage%2F4" title="http://collection.britishmuseum.org/id/object/JCF12245/image/4" class="explicit">http://collection.britishmuseum.org/id/object/JCF12245/image/4</a></span>,
                                                        <span><a href="/resource?uri=http%3A%2F%2Fcollection.britishmuseum.org%2Fid%2Fobject%2FJCF12245%2Finscription%2F1" title="http://collection.britishmuseum.org/id/object/JCF12245/inscription/1" class="explicit">http://collection.britishmuseum.org/id/object/JCF12245/inscription/1</a></span>
                                                    </div></td></tr></tbody></table>
                                </div>
                            </div>
                        </div>
                    </div>
                </div>
            </div>
            <footer>
                <p>                            
                    © 2009-2012 Ontotext AD. All rights reserved.
                </p>
                <p>
                    <a href="http://www.ontotext.com"><img height="36" alt="Ontotext AD" width="140" src="/img/ontotext.png"></a>
                </p>
            </footer>
            <div id="alertsContainers" style="display: none;">
            </div>
        </div>
    </body>
</html>
'''

# %%
from bs4 import BeautifulSoup
#soup = BeautifulSoup(html_doc, 'html.parser')
soup = BeautifulSoup(html_doc, 'xml')
#BeautifulSoup(markup, "xml")
#print(soup.prettify())
#soup.title
#for link in soup.find_all('a'):
#    print(link.get('href')) #get all the links

print(soup.get_text())
links=soup.get_text()
# Out:
# http://collection.britishmuseum.org/id/object/JCF9001
#
#
#
#
# http://collection.britishmuseum.org/id/object/J_1982-0701-0-3
#
#
#
#
# http://collection.britishmuseum.org/id/object/147
#
#
#
#
# http://collection.britishmuseum.org/id/object/JCF8994
#
#
#
#
# http://collection.britishmuseum.org/id/object/J_1982-0701-0-5
#
#
#
#
# http://collection.britishmuseum.org/id/object/149
#
#
#
#
# http://collection.britishmuseum.org/id/object/JCF12245
#
#
#
#
# http://collection.britishmuseum.org/id/object/J_1982-0701-0-6-1-10
#
#
#
#
# http://collection.britishmuseum.org/id/object/150
#
#
#
#
# http://collection.britishmuseum.org/id/object/JCF8989
#
#
#
#
# http://collection.britishmuseum.org/id/object/J_1982-0701-0-7
#
#
#
#
# http://collection.britishmuseum.org/id/object/151
#
#
#
#
# http://collection.britishmuseum.org/id/object/JCF11686
#
#
#
#
# http://collection.britishmuseum.org/id/object/J_1981-0223-0-1
#
#
#
#
# http://collection.britishmuseum.org/id/object/1388
#
#
#
#
# ...

# %%
# Out:
# unicode

# %%
import re
links_parsed = re.split("\n+",links)
links_parsed[1001]
list_links=links_parsed[5:200]

# %%
soup1 = BeautifulSoup(html_doc, 'html.parser')
# Out:
# u'\n\n\n\n\n\n\nhttp://collection.britishmuseum.org/id/object/JCF9001\n\n\n\n\nhttp://collection.britishmuseum.org/id/object/J_1982-0701-0-3\n\n\n\n\nhttp://collection.britishmuseum.org/id/object/147\n\n\n\n\nhttp://collection.britishmuseum.org/id/object/JCF8994\n\n\n\n\nhttp://collection.britishmuseum.org/id/object/J_1982-0701-0-5\n\n\n\n\nhttp://collection.britishmuseum.org/id/object/149\n\n\n\n\nhttp://collection.britishmuseum.org/id/object/JCF12245\n\n\n\n\nhttp://collection.britishmuseum.org/id/object/J_1982-0701-0-6-1-10\n\n\n\n\nhttp://collection.britishmuseum.org/id/object/150\n\n\n\n\nhttp://collection.britishmuseum.org/id/object/JCF8989\n\n\n\n\nhttp://collection.britishmuseum.org/id/object/J_1982-0701-0-7\n\n\n\n\nhttp://collection.britishmuseum.org/id/object/151\n\n\n\n\nhttp://collection.britishmuseum.org/id/object/JCF11686\n\n\n\n\nhttp://collection.britishmuseum.org/id/object/J_1981-0223-0-1\n\n\n\n\nhttp://collection.britishmuseum.org/id/object/1388\n\n\n\n\nhttp://co
# ...

# %%
from lxml import html
import requests
page = requests.get('http://collection.britishmuseum.org/id/object/R_1919-0101-0-94')

tree = html.fromstring(page.content)
#This will create a list of buyers:
#buyers = tree.xpath('//div[@title="buyer-name"]/text()')
#buyers = tree.xpath('//div[@title="http://collection.britishmuseum.org/id/ontology/PX_curatorial_comment"]/text()')

#This will create a list of prices
#prices = tree.xpath('//span[@class="item-price"]/text()')
#print 'Buyers: ', buyers
#print 'Prices: ', prices

# %%
print page.content
# Out:
# <!DOCTYPE html>
# <html>
#     <head>
#         <meta charset="UTF-8">
#         <title>
#             GENERIC R_1919-0101-0-94
#         </title>
#         <link href="/favicon.ico" rel="icon" type="image/x-icon">
#         <link type="text/css" rel="stylesheet" href="/css/summer-MQovY3NzL2Jvb3RzdHJhcC5taW4uY3Nz.css">
#         <link type="text/css" rel="stylesheet" href="/css/forest-eNoz5NJPLi7WT8svSi0u0U0sLclPzs8tyEktSdUDiqNIJgMphGByaXFJfq5uSUZqbqp+VmFpalGlbmmmLkQYpAwA0IAhYg.css">
#         <link type="text/css" rel="stylesheet" href="/css/eNoz4NJPLi7WT8svSi0u0QUS+aVFyal6QDGIRH55Tmaubnl+UXZSal5yBkIiLTU1JSkxORskAgBf6BkO.css">
#         <script type="text/javascript" src="/js/summer-eNpNzDEKgDAMQNHduzSlLp4nlggtjalJCnp7Fwuu78NPS6wW6zVIn5BggxW4nFDt54DDJQv3Rk4z2WAmDVjxnnSIknkwyQXbxF3EzRX7930Bkh0nzA.js"></script>
# ...

# %%
soup2 = BeautifulSoup(page.content,'html')
#print(soup2.get_text())

# %%
page = requests.get('http://collection.britishmuseum.org/id/object/R_1919-0101-0-94')
soup2 = BeautifulSoup(page.content,'html')
a=soup2.find_all('tr','odd')
b=a[6].find_all('span')
print b[3]
#c=b[3].find_all('span','span')
#print c
# Out:
# <span><span>English
#
# From Whitfield 1982:
#
# These fragments of a banner (see Fig. 86), as pointed out by Stein in Serindia, are clearly from the same series as those shown in Pl.31 and Pl.41, characterized by the use of opaque white pigment that has tended to flake away, and by simplified landscape forms—low hills—separating the different scenes. A charmingly domestic touch is added by the lady, with the rather full figure and costume associated with the Tang, who is milking the cow.</span></span>

# %%
def get_curatorial(list_of_links):

    curatorial = {}
    for links in list_of_links: #add that it usually starts from links_parsed[1] and finishes at links_parsed[end-1]
        temp_curatorial = {}
        #WRITE A FUNCTION TO PULL OUT OF THE LINK THE FRAGMENT I NEED
        page = requests.get(links)
        soup = BeautifulSoup(page.content,'html')
        hrefs = soup.find_all('a', href='/resource/bmo/PX_curatorial_comment')
        try:
            link = hrefs[0]
            temp_curatorial = link.findNext('div')
            #print 'length of temp_curatorial: {}'.format(len(temp_curatorial))
            curatorial[links] = temp_curatorial
            print 'successfully added {}'.format(links)
        except:
            print "OOPS for {}".format(links)
            curatorial[links] = None
    return curatorial
g = get_curatorial(list_links)
# Out:
# length of temp_curatorial: 5
# successfully added http://collection.britishmuseum.org/id/object/J_1982-0701-0-5
# length of temp_curatorial: 5
# successfully added http://collection.britishmuseum.org/id/object/149
# length of temp_curatorial: 5
# successfully added http://collection.britishmuseum.org/id/object/JCF12245
# length of temp_curatorial: 5
# successfully added http://collection.britishmuseum.org/id/object/J_1982-0701-0-6-1-10
# length of temp_curatorial: 5
# successfully added http://collection.britishmuseum.org/id/object/150
# length of temp_curatorial: 3
# successfully added http://collection.britishmuseum.org/id/object/JCF8989
# length of temp_curatorial: 3
# successfully added http://collection.britishmuseum.org/id/object/J_1982-0701-0-7
# length of temp_curatorial: 3
# successfully added http://collection.britishmuseum.org/id/object/151
# OOPS for http://collection.britishmuseum.org/id/object/JCF11686
# ...

# %%
#def get_physical(list_of_links):
    
physical = {}
#    for links in list_of_links: #add that it usually starts from links_parsed[1] and finishes at links_parsed[end-1]
temp_physical = {}
page = requests.get('http://collection.britishmuseum.org/id/object/R_1919-0101-0-94')
soup = BeautifulSoup(page.content,'html')
hrefs = soup.find_all('a', href='/resource/bmo/PX_physical_description')
#        try:
link = hrefs[0]
temp_physical = link.findNext('div')
#            print 'length of temp_physical: {}'.format(len(temp_physical))
 #           physical[links] = temp_physical
  #          print 'successfully added {}'.format(links)
   #     except:
   #         print "OOPS for {}".format(links)
    #        physical[links] = None
    #return physical
temp_physical
# Out:
# <div>\n<span><span>Two fragments of a banner showing two scenes from the Life of the Buddha, in a landscape setting. The top fragment illustrates the simultaneous births of sheep, the bottom fragment a cow and a horse, and a lady in Tang costume milking the cow. Blank cartouches on alternate sides of the scenes. Ink and colours on silk.</span></span>\n</div>

# %%
type(g)
# Out:
# dict

# %%
a_hrefs = soup2.find_all('a', href='/resource/bmo/PX_curatorial_comment')

# %%
link = a_hrefs[0]

# %%
[item ** 2 for item in range(20) if (item % 2) == 0]
# Out:
# [0, 4, 16, 36, 64, 100, 144, 196, 256, 324]

# %%
# Out:
# generator

# %%
children = [child for child in link.descendants]

# %%
link
# Out:
# <a href="/resource/bmo/PX_curatorial_comment" title="http://collection.britishmuseum.org/id/ontology/PX_curatorial_comment">bmo:PX_curatorial_comment</a>

# %%
div = [d for d in link.findNext('div')]

# %%
div
# Out:
# [u'\n',
#  <span><span>Chinese\n\nFrom Whitfield 1982:\n\n\u9019\u4e9b\u5e61\u756b\u7684\u788e\u7247(\u898bFig. 86)\uff0c\u6b63\u5982\u65af\u5766\u56e0\u5728\u300a\u897f\u57df\u300b\u4e2d\u6307\u51fa\u7684---\u5f88\u660e\u986f\u4f86\u81ea\u571631 \u548c\u571641\u4e2d\u8868\u73fe\u7684\u76f8\u540c\u7684\u7cfb\u5217\uff0c\u4f7f\u7528\u4e0d\u900f\u660e\u7684\u767d\u8272\u9854\u6599\u4f86\u986f\u793a\u9019\u4e00\u7279\u5fb5\uff0c\u800c\u767d\u8272\u9854\u6599\u5df2\u7d93\u812b\u843d\u4e86\u3002\u7528\u7c21\u55ae\u5316\u7684\u98a8\u666f\u2014\u2014\u4f4e\u77ee\u7684\u5c0f\u4e18\u2014\u2014\u5206\u9694\u4e0d\u540c\u7684\u5834\u666f\uff0c\u4e00\u500b\u8eab\u8457\u5510\u4ee3\u670d\u88dd\u7684\u64e0\u725b\u5976\u7684\u8c50\u6eff\u5a66\u5973\uff0c\u4f7f\u756b\u9762\u589e\u52a0\u4e86\u4ee4\u4eba\u9676\u9189\u7684\u5bb6\u5ead\u6c23\u606f\u3002</span></span>,
#  u',\n                                                        ',
# ...

# %%
len(div)
span = [s for s in div.findNext('span')]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-288-f53a46809780> in <module>()
#       1 len(div)
# ----> 2 span = [s for s in div.findNext('span')]
#
# AttributeError: 'list' object has no attribute 'findNext'

# %%
link.fetchNextSiblings()
# Out:
# []

# %%
len(descendants)
# Out:
# 1

# %%
children
# Out:
# [u'bmo:PX_curatorial_comment']

# %%
#http://collection.britishmuseum.org/id/object/JCF9001
page = requests.get('http://collection.britishmuseum.org/id/object/JCF9001')
soup2 = BeautifulSoup(page.content,'html')
a=soup2.find_all('tr','odd')
#print a
b=a[7].find_all('span')
#print b[3]
#c=b[3].find_all('span','span')
print c
# Out:
# [<tr class="odd"><td><span>\n<a href="/resource/ecrm/P45_consists_of" title="http://erlangen-crm.org/current/P45_consists_of">ecrm:P45_consists_of</a></span></td><td>\n<div>\n<span><a class="explicit" href="/resource/thes/x11409" title="http://collection.britishmuseum.org/id/thesauri/x11409">thes:x11409</a></span>\n</div></td></tr>, <tr class="odd"><td><span>\n<a href="/resource/bmo/PX_has_main_representation" title="http://collection.britishmuseum.org/id/ontology/PX_has_main_representation">bmo:PX_has_main_representat...</a></span></td><td>\n<div>\n<span><a class="explicit" href="/resource?uri=http%3A%2F%2Fwww.britishmuseum.org%2Fcollectionimages%2FAN00079%2FAN00079321_001_l.jpg" title="http://www.britishmuseum.org/collectionimages/AN00079/AN00079321_001_l.jpg">http://www.britishmuseum.org/collectionimages/AN00079/AN00079321_001_l.jpg</a></span>\n</div></td></tr>, <tr class="odd"><td><span>\n<a href="/resource/ecrm/P52_has_current_owner" title="http://erlangen-crm.org/current/P52_ha
# ...

# %%
page = requests.get('http://collection.britishmuseum.org/id/object/JCF8994')
soup2 = BeautifulSoup(page.content,'html')
a=soup2.find_all('tr','odd')
b=a[6].find_all('span')
print b[3]
# Out:
# <span><span>Clark 1992
#
#
#
# A young woman, probably the daughter of a wealthy samurai family, is out walking accompanied by a maid. She wears an 'age-boshi' cloth to protect her oiled hairdo from the dirt and dust. Her black kimono with long, flowing sleeves is decorated with a design of delicately painted autumn plants and grasses beside a winding river, and there is much use of gold, both to follow the ink contours of the drapery with slender gold outlines and also in the roundels of the thick brocade 'obi'.
#
#
#
# ...

# %%
page = requests.get('http://collection.britishmuseum.org/id/object/JCF8989')
soup2 = BeautifulSoup(page.content,'html')
a=soup2.find_all('tr','odd')
#print a
b=a[8].find_all('span')
print b[2]
# Out:
# <span>Hizo Nihon bijutsu taikan Vol 2
#
#
#
# The title affixed to the outside of the scroll reads 'Jichosai-hitsu Chushingura emaki' (Chushingura Picture Scroll by Jichosai), and though the scroll is unsigned, the style displays the humorous manner typical of the artist. Jichosai studied, on his own, the brush techniques of Toba Sojo and Kokan, among others, developing a unique style of his own and painting large numbers of light, humorous paintings ('kyoga').
#
#
#
# ...

# %%
page = requests.get('http://collection.britishmuseum.org/id/object/R_1919-0101-0-10')
soup2 = BeautifulSoup(page.content,'html')
a=soup2.find_all('tr','odd')
print a
b=a[6].find_all('span')
print b[4]
# Out:
# [<tr class="odd"><td><span>\n<a href="/resource/ecrm/P45_consists_of" title="http://erlangen-crm.org/current/P45_consists_of">ecrm:P45_consists_of</a></span></td><td>\n<div>\n<span><a class="explicit" href="/resource/thes/x11726" title="http://collection.britishmuseum.org/id/thesauri/x11726">thes:x11726</a></span>\n</div></td></tr>, <tr class="odd"><td><span>\n<a href="/resource/bmo/PX_has_main_representation" title="http://collection.britishmuseum.org/id/ontology/PX_has_main_representation">bmo:PX_has_main_representat...</a></span></td><td>\n<div>\n<span><a class="explicit" href="/resource?uri=http%3A%2F%2Fwww.britishmuseum.org%2Fcollectionimages%2FAN00000%2FAN00000238_003_l.jpg" title="http://www.britishmuseum.org/collectionimages/AN00000/AN00000238_003_l.jpg">http://www.britishmuseum.org/collectionimages/AN00000/AN00000238_003_l.jpg</a></span>\n</div></td></tr>, <tr class="odd"><td><span>\n<a href="/resource/ecrm/P52_has_current_owner" title="http://erlangen-crm.org/current/P52_ha
# ...

# %%
page = requests.get('http://collection.britishmuseum.org/id/object/R_1919-0101-0-13')
soup2 = BeautifulSoup(page.content,'html')
a=soup2.find_all('tr','odd')
#print a
b=a[6].find_all('span')
print b[3]
# Out:
# <span><span>English
#
# From Whitfield 1983:
#
# This impressive standing figure of the Bodhisattva Avalokitesvara, holding a willow spray in his right hand and a sprinkler vase in his left, displays features shared with other representations of the same Bodhisattva, such as those shown in Pls. 2 and 3 and in Vol. 1, Pl. 23.
#
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-205-56fe1f29ebfa> in <module>()
#       1 dit=[]
# ----> 2 dit[0]=b[3]
#
# IndexError: list assignment index out of range
